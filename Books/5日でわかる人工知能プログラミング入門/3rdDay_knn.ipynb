# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], test_size=0.3, random_state=0)

# %%
import pandas as pd
pd.DataFrame(x_train, columns=iris_dataset.feature_names)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.0               2.0                3.5               1.0
# 1                  6.5               3.0                5.5               1.8
# 2                  6.7               3.3                5.7               2.5
# 3                  6.0               2.2                5.0               1.5
# 4                  6.7               2.5                5.8               1.8
# 5                  5.6               2.5                3.9               1.1
# 6                  7.7               3.0                6.1               2.3
# 7                  6.3               3.3                4.7               1.6
# 8                  5.5               2.4                3.8               1.1
# 9                  6.3               2.7                4.9               1.8
# 10                 6.3               2.8                5.1               1.5
# 11                 4.9               2.5                4.5               1.7
# 12                 6.3               2.5                5.0               1.9
# 13                 7.0               3.2                4.7               1.4
# 14                 6.5               3.0                5.2               2.0
# 15                 6.0               3.4                4.5               1.6
# 16                 4.8               3.1                1.6               0.2
# 17                 5.8               2.7                5.1               1.9
# 18                 5.6               2.7                4.2               1.3
# 19                 5.6               2.9                3.6               1.3
# 20                 5.5               2.5                4.0               1.3
# 21                 6.1               3.0                4.6               1.4
# 22                 7.2               3.2                6.0               1.8
# 23                 5.3               3.7                1.5               0.2
# 24                 4.3               3.0                1.1               0.1
# 25                 6.4               2.7                5.3               1.9
# 26                 5.7               3.0                4.2               1.2
# 27                 5.4               3.4                1.7               0.2
# 28                 5.7               4.4                1.5               0.4
# 29                 6.9               3.1                4.9               1.5
# ..                 ...               ...                ...               ...
# 75                 5.8               4.0                1.2               0.2
# 76                 7.7               2.8                6.7               2.0
# 77                 5.1               3.8                1.5               0.3
# 78                 4.7               3.2                1.6               0.2
# 79                 7.4               2.8                6.1               1.9
# 80                 5.0               3.3                1.4               0.2
# 81                 6.3               3.4                5.6               2.4
# 82                 5.7               2.8                4.1               1.3
# 83                 5.8               2.7                3.9               1.2
# 84                 5.7               2.6                3.5               1.0
# 85                 6.4               3.2                5.3               2.3
# 86                 6.7               3.0                5.2               2.3
# 87                 6.3               2.5                4.9               1.5
# 88                 6.7               3.0                5.0               1.7
# 89                 5.0               3.0                1.6               0.2
# 90                 5.5               2.4                3.7               1.0
# 91                 6.7               3.1                5.6               2.4
# 92                 5.8               2.7                5.1               1.9
# 93                 5.1               3.4                1.5               0.2
# 94                 6.6               2.9                4.6               1.3
# 95                 5.6               3.0                4.1               1.3
# 96                 5.9               3.2                4.8               1.8
# 97                 6.3               2.3                4.4               1.3
# 98                 5.5               3.5                1.3               0.2
# 99                 5.1               3.7                1.5               0.4
# 100                4.9               3.1                1.5               0.1
# 101                6.3               2.9                5.6               1.8
# 102                5.8               2.7                4.1               1.0
# 103                7.7               3.8                6.7               2.2
# 104                4.6               3.2                1.4               0.2
#
# [105 rows x 4 columns]

# %%
pd.DataFrame(x_test, columns=iris_dataset.feature_names)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 5.8               2.8                5.1               2.4
# 1                 6.0               2.2                4.0               1.0
# 2                 5.5               4.2                1.4               0.2
# 3                 7.3               2.9                6.3               1.8
# 4                 5.0               3.4                1.5               0.2
# 5                 6.3               3.3                6.0               2.5
# 6                 5.0               3.5                1.3               0.3
# 7                 6.7               3.1                4.7               1.5
# 8                 6.8               2.8                4.8               1.4
# 9                 6.1               2.8                4.0               1.3
# 10                6.1               2.6                5.6               1.4
# 11                6.4               3.2                4.5               1.5
# 12                6.1               2.8                4.7               1.2
# 13                6.5               2.8                4.6               1.5
# 14                6.1               2.9                4.7               1.4
# 15                4.9               3.6                1.4               0.1
# 16                6.0               2.9                4.5               1.5
# 17                5.5               2.6                4.4               1.2
# 18                4.8               3.0                1.4               0.3
# 19                5.4               3.9                1.3               0.4
# 20                5.6               2.8                4.9               2.0
# 21                5.6               3.0                4.5               1.5
# 22                4.8               3.4                1.9               0.2
# 23                4.4               2.9                1.4               0.2
# 24                6.2               2.8                4.8               1.8
# 25                4.6               3.6                1.0               0.2
# 26                5.1               3.8                1.9               0.4
# 27                6.2               2.9                4.3               1.3
# 28                5.0               2.3                3.3               1.0
# 29                5.0               3.4                1.6               0.4
# 30                6.4               3.1                5.5               1.8
# 31                5.4               3.0                4.5               1.5
# 32                5.2               3.5                1.5               0.2
# 33                6.1               3.0                4.9               1.8
# 34                6.4               2.8                5.6               2.2
# 35                5.2               2.7                3.9               1.4
# 36                5.7               3.8                1.7               0.3
# 37                6.0               2.7                5.1               1.6
# 38                5.9               3.0                4.2               1.5
# 39                5.8               2.6                4.0               1.2
# 40                6.8               3.0                5.5               2.1
# 41                4.7               3.2                1.3               0.2
# 42                6.9               3.1                5.1               2.3
# 43                5.0               3.5                1.6               0.6
# 44                5.4               3.7                1.5               0.2

# %%
y_train
# Out:
# array([1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 2, 2, 1, 2, 1, 0, 2, 1, 1, 1, 1,
#        2, 0, 0, 2, 1, 0, 0, 1, 0, 2, 1, 0, 1, 2, 1, 0, 2, 2, 2, 2, 0, 0,
#        2, 2, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 0, 1, 2, 2, 0, 0, 0, 1, 1, 0,
#        0, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 0, 0, 2, 0, 2, 1, 1, 1, 2, 2, 1,
#        1, 0, 1, 2, 2, 0, 1, 1, 1, 1, 0, 0, 0, 2, 1, 2, 0])

# %%
y_test
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1, 1, 1, 2, 0, 2, 0,
#        0])

# %%
# mglearn は matplotlib のヘルパーモジュール
import mglearn
import matplotlib.pyplot as plt

# %%
iris_dataframe = pd.DataFrame(x_train, columns=iris_dataset.feature_names)

# %% [markdown]
# scatter_matrix 関数を使うと、一連の変数のペアプロットを作成して散布図にできる。
# scatter_matrix 関数の引数は以下
#
# * frame : pandas の DataFrame
# * alpha : 透明度。0:透明 ～ 1:不透明 の間の数値
# * s : サイズ
# * figsize : ウインドウサイズ(インチ)
# * marker : マーカーの形( 'o', 'x', '.')
# * hist_kwds : ヒストグラムに渡されるプロットキーワード
# * cmap : カラーマップ

# %%
# scatter_matrix は、一連の変数のペアプロットを作成して散布図にしてくれる
from pandas.plotting import scatter_matrix
grr = scatter_matrix(iris_dataframe, c=y_train, figsize=(15, 15), marker='o', hist_kwds={'bins': 20}, s=60, alpha=.8, cmap=mglearn.cm3)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
# 予測（1つ目のデータ）
import numpy as np
# setosa の がく片の長さ、がく片の幅、花弁の長さ、花弁の幅
x_new = np.array([[5.0, 2.9, 1.0, 0.2]])
prediction1 = knn.predict(x_new)
print(iris_dataset['target_names'][prediction1])
# Out:
# ['setosa']

# %%
# 予測（2つ目のデータ）
x_new = np.array([[6.0, 2.7, 5.1, 1.6]])
prediction1 = knn.predict(x_new)
print(iris_dataset['target_names'][prediction1])
# Out:
# ['virginica']

# %%
# モデルの評価（正解率の算出）
y_pred = knn.predict(x_test)
# 予測結果
print('予測結果')
print(y_pred)
# 正解ラベル
print('正解ラベル')
print(y_test)
# 正解率=予測精度
print('予測精度')
print(np.mean(y_pred == y_test))
# Out:
# 予測結果
# [2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 2 0 0 1 1 0 2 1 0 2 2 1 0
#  2 1 1 2 0 2 0 0]
# 正解ラベル
# [2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 2 0 0 1 1 0 2 1 0 2 2 1 0
#  1 1 1 2 0 2 0 0]
# 予測精度
# 0.9777777777777777
